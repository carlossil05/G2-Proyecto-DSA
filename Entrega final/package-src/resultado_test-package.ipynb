# %%
import pandas as pd
from model.predict import make_prediction

sample_input_data = pd.read_csv("model/datasets/housing_test.csv")
result = make_prediction(input_data=sample_input_data)

# %%
result
# Out:
# {'predictions': [np.float64(13.635679994241398),
#   np.float64(12.87903567251437),
#   np.float64(12.688285979145174),
#   np.float64(13.065035486623874),
#   np.float64(13.602789400793075),
#   np.float64(12.921929355711905),
#   np.float64(13.0108199766772),
#   np.float64(12.634206508410823),
#   np.float64(12.562640140932878),
#   np.float64(12.947503130396044),
#   np.float64(13.122334975585243),
#   np.float64(13.541812288130272),
#   np.float64(13.734430663619248),
#   np.float64(12.648371781859105),
#   np.float64(13.297217880777694),
#   np.float64(12.7078124839051),
#   np.float64(13.14035696605107),
#   np.float64(12.93603828146228),
#   np.float64(12.734305519868224),
#   np.float64(13.150802875433005),
#   np.float64(12.914776116806335),
#   np.float64(13.12893545213033),
#   np.float64(13.025549446736687),
#   np.float64(12.383786763512207),
#   np.float64(12.399521118371748),
#   np.float64(12.392960430902813),
#   np.float64(12.923738039195943),
# ...

# %%
import numpy as np

np.exp(result['predictions'])
# Out:
# array([ 835411.7484767 ,  392007.27313425,  323931.05507265, ...,
#         586470.91804562,  744948.51977038, 1298730.21675267],
#       shape=(1228,))
