# %%
import numpy as np
import pandas as pd

from .config.core import config
from .pipeline import housing_pipe
from .processing.data_manager import load_dataset, save_pipeline


def run_training() -> None:
    """Train the model."""

    # Load pre-split training dataset
    data = load_dataset(file_name=config.app_config.train_data_file)

    # Separate target and features
    X_train = data[config.model.features]
    y_train = data[config.model.target]

    # Fit the regression model
    housing_pipe.fit(X_train, y_train)

    # Persist trained pipeline
    save_pipeline(pipeline_to_persist=housing_pipe)


if __name__ == "__main__":
    run_training()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 from config.core import config
#       5 from pipeline import housing_pipe
#       6 from processing.data_manager import load_dataset, save_pipeline
#
# File G:\Mi unidad\Carlos Silva\MIAD\4304 Despliegue soluciones analiticas\Proyecto\git\Entrega final\package-src\model\config\core.py:7
#       4 from pydantic import BaseModel
#       5 from strictyaml import YAML, load
# ----> 7 import model
#       9 # Project Directories
#      10 PACKAGE_ROOT = Path(model.__file__).resolve().parent
#
# ModuleNotFoundError: No module named 'model'
