# %%
#Librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import plotly.express as px
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
# !pip install xgboost
from xgboost import XGBRegressor

# %%
#Cargar datos a un dataframe
df = pd.read_csv('../../data/USA Housing Dataset.csv')

#Cantidad de observaciones y variables del dataset
df.shape
# Out:
# (4140, 18)

# %%
#Tipo de datos del dataset
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
#Vista de las primeras observaciones del dataset
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
#Estadísticas descriptivas de las variables numéricas
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.140000e+03  4140.000000  4140.000000   4140.000000  4.140000e+03
# mean   5.530629e+05     3.400483     2.163043   2143.638889  1.469764e+04
# std    5.836865e+05     0.903939     0.784733    957.481621  3.587684e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.200000e+05     3.000000     1.750000   1470.000000  5.000000e+03
# 50%    4.600000e+05     3.000000     2.250000   1980.000000  7.676000e+03
# 75%    6.591250e+05     4.000000     2.500000   2620.000000  1.100000e+04
# max    2.659000e+07     8.000000     6.750000  10040.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4140.000000  4140.000000  4140.000000  4140.000000  4140.000000
# mean      1.514130     0.007488     0.246618     3.452415  1831.351449
# std       0.534941     0.086219     0.790619     0.678533   861.382947
# ...

# %%
#Estadística descriptiva de las variables categóricas
df.describe(include='object')
# Out:
#                        date                 street     city  statezip country
# count                  4140                   4140     4140      4140    4140
# unique                   68                   4079       43        77       1
# top     2014-06-23 00:00:00  2520 Mulberry Walk NE  Seattle  WA 98103     USA
# freq                    142                      4     1415       128    4140

# %%
#Cantidad de datos vacíos del dataset
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
#Porcentaje de observaciones por ciudad
df['city'].value_counts(normalize=True)
# Out:
# city
# Seattle               0.341787
# Renton                0.063043
# Bellevue              0.062802
# Redmond               0.050483
# Kent                  0.040338
# Kirkland              0.040097
# Issaquah              0.039130
# Auburn                0.039130
# Sammamish             0.038164
# Federal Way           0.031643
# Shoreline             0.027053
# Woodinville           0.024879
# Maple Valley          0.021739
# Mercer Island         0.019565
# Snoqualmie            0.015700
# Burien                0.015459
# Kenmore               0.014010
# Des Moines            0.012560
# North Bend            0.010870
# Covington             0.009420
# Duvall                0.009420
# Lake Forest Park      0.007971
# Newcastle             0.007488
# Bothell               0.007246
# SeaTac                0.007005
# Enumclaw              0.006763
# Tukwila               0.006763
# Vashon                0.006763
# Carnation             0.004348
# Normandy Park         0.003865
# ...

# %%
#Convertir columna date a datetime para facilitar exploración
df['date'] = pd.to_datetime(df['date'])
#Se agrupan por mes para evaluar la fecha de las observaciones
df.groupby(df['date'].dt.to_period('M')).size()
# Out:
# date
# 2014-05    1308
# 2014-06    2179
# 2014-07     653
# Freq: M, dtype: int64

# %%
#Histogramas de los datos
numeric_cols = df.select_dtypes(include='number').columns

#Para cada columna numérica se grafica un histograma
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], bins=30)
    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Cuenta")
    plt.show()

# %%
#Matriz de correlación
corr=df.corr(numeric_only=True)
corr
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.188765   0.317785     0.418528  0.045964  0.143180
# bedrooms       0.188765  1.000000   0.542549     0.590110  0.065747  0.178908
# bathrooms      0.317785  0.542549   1.000000     0.760353  0.097497  0.487462
# sqft_living    0.418528  0.590110   0.760353     1.000000  0.194226  0.345130
# sqft_lot       0.045964  0.065747   0.097497     0.194226  1.000000 -0.001113
# floors         0.143180  0.178908   0.487462     0.345130 -0.001113  1.000000
# waterfront     0.131401 -0.001286   0.080152     0.126157  0.019229  0.021278
# view           0.217553  0.105512   0.210590     0.308098  0.071264  0.030604
# condition      0.030327  0.016503  -0.123024    -0.069315  0.012016 -0.275212
# sqft_above     0.355214  0.478124   0.687679     0.874881  0.203190  0.524777
# sqft_basement  0.204066  0.329862   0.292170     0.439053  0.023567 -0.261826
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title("Mapa de calor de correlación de variables numéricas")
plt.show()

# %%
#Calcular el precio por sqft
df['price_per_sqft'] = df['price'] / df['sqft_lot']

# Agrupar promedio de precio por sqft por ciudad
precio_ciudad = df.groupby('city')['price_per_sqft'].mean().sort_values(ascending=False)
precio_ciudad
# Out:
# city
# Seattle               153.080670
# Issaquah              116.238364
# Medina                101.508896
# Yarrow Point           97.458222
# Mercer Island          86.239520
# Snoqualmie             79.359430
# Bellevue               78.837116
# Kirkland               78.262402
# Beaux Arts Village     76.020408
# Redmond                69.998415
# Sammamish              68.903121
# Newcastle              65.892227
# Clyde Hill             61.438731
# Bothell                60.077391
# Kent                   53.690288
# Kenmore                50.883899
# Snoqualmie Pass        50.665895
# Maple Valley           50.313523
# Shoreline              49.588081
# Renton                 48.716468
# Covington              44.357965
# Normandy Park          42.216105
# Lake Forest Park       41.407580
# Des Moines             35.782268
# North Bend             35.444478
# Duvall                 35.389759
# Burien                 34.146018
# Tukwila                32.344806
# ...

# %%
precio_ciudad = df.groupby('city')['price_per_sqft'].mean().reset_index()

# Inicializar geolocator
geolocator = Nominatim(user_agent="wa_price_map")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# Se agrega el estado de Washington en USA a cada ciudad para facilitar el geocode
def safe_geocode(city):
    try:
        return geocode(f"{city}, Washington, USA")
    except:
        return None

#Encontrar las coordenadas geográficas de cada ciudad
precio_ciudad['location'] = precio_ciudad['city'].apply(safe_geocode)
precio_ciudad['lat'] = precio_ciudad['location'].apply(lambda loc: loc.latitude if loc else None)
precio_ciudad['lon'] = precio_ciudad['location'].apply(lambda loc: loc.longitude if loc else None)

# %%
# Gráfica geográfica usando plotly express scatter_map
fig = px.scatter_map(
    precio_ciudad,
    lat='lat',
    lon='lon',
    size='price_per_sqft',
    color='price_per_sqft',
    hover_name='city',
    color_continuous_scale='Viridis',
    map_style='carto-positron',
    zoom=7,
    title='Precio promedio por sqft por ciudad',
    width=700,
    height=700,
)
fig.show()

# %% [markdown]
# **2. Preparación de datos**

# %%
#Cargar datos a un dataframe
df = pd.read_csv('../../data/USA Housing Dataset.csv')

# %%
# Eliminar columnas no numéricas
df = df.drop(columns=['date', 'street', 'statezip', 'country'])

# Filtrar filas con precio > 0
df = df[df['price'] > 0]

# Codificar la columna 'city' con OneHotEncoder
df = pd.get_dummies(df, columns=['city'])

# Separar variables predictoras (X) y objetivo (y)
X = df.drop(columns=['price'])
y_log = np.log(df['price'])

# Verificar el resultado
print(X.head())
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       3.0       2.00         1340      1384     3.0           0     0
# 1       4.0       3.25         3540    159430     2.0           0     0
# 2       5.0       6.50         7270    130017     2.0           0     0
# 3       3.0       2.25          998       904     2.0           0     0
# 4       5.0       2.75         3060      7015     1.0           0     0
#
#    condition  sqft_above  sqft_basement  ...  city_SeaTac  city_Seattle  \
# 0          3        1340              0  ...        False          True
# 1          3        3540              0  ...        False         False
# 2          3        6420            850  ...        False         False
# 3          3         798            200  ...        False          True
# 4          5        1600           1460  ...        False          True
#
#    city_Shoreline  city_Skykomish  city_Snoqualmie  city_Snoqualmie Pass  \
# ...

# %% [markdown]
# **3. Modelos**

# %%
# Se crean las particiones de entrenamiento y prueba
XTrain, XTest, yTrain, yTest = train_test_split(X, y_log, test_size=0.30, random_state=0)

# Validación cruzada
cv = KFold(n_splits=5, shuffle=True, random_state=0)

# Resultados
print("Tamaño total:", df.shape)
print("Entrenamiento:", XTrain.shape, yTrain.shape)
print("Prueba:", XTest.shape, yTest.shape)
# Out:
# Tamaño total: (4091, 56)
# Entrenamiento: (2863, 55) (2863,)
# Prueba: (1228, 55) (1228,)

# %% [markdown]
# 3.1. Regresión lineal

# %%
Reg_Lineal = LinearRegression()
r2_scores = cross_val_score(Reg_Lineal, XTotal, YTotal, cv=cv, scoring='r2')
Reg_Lineal.fit(XTrain, yTrain)
yPred = Reg_Lineal.predict(XTest)

mae_rl = mean_absolute_error(yTest, yPred)
mse_rl = mean_squared_error(yTest, yPred)
rmse_rl = np.sqrt(mse_rl)
r2_rl = r2_score(yTest, yPred)

print(f"MAE: {mae_rl:.3f}")
print(f"MSE: {mse_rl:.3f}")
print(f"RMSE: {rmse_rl:.3f}")
print(f"R²: {r2_rl:.3f}")
# Out:
# MAE: 0.196
# MSE: 0.086
# RMSE: 0.294
# R²: 0.701

# %% [markdown]
# 3.2. Random Forest

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=0)
rf_cv_scores = cross_val_score(rf, XTotal, YTotal, cv=cv, scoring='r2')
rf.fit(XTrain, yTrain)
yPred_rf = rf.predict(XTest)

mae_rf = mean_absolute_error(yTest, yPred_rf)
mse_rf = mean_squared_error(yTest, yPred_rf)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(yTest, yPred_rf)

print(f"MAE: {mae_rf:.3f}")
print(f"MSE: {mse_rf:.3f}")
print(f"RMSE: {rmse_rf:.3f}")
print(f"R²: {r2_rf:.3f}")
# Out:
# MAE: 0.200
# MSE: 0.086
# RMSE: 0.294
# R²: 0.701

# %% [markdown]
# 3.3. Gradient Boosting Regressor

# %%
gb = GradientBoostingRegressor(n_estimators=100, random_state=0)
gb_cv_scores = cross_val_score(gb, XTotal, YTotal, cv=cv, scoring='r2')
gb.fit(XTrain, yTrain)
yPred_gb = gb.predict(XTest)

mae_gb = mean_absolute_error(yTest, yPred_gb)
mse_gb = mean_squared_error(yTest, yPred_gb)
rmse_gb = np.sqrt(mse_gb)
r2_gb = r2_score(yTest, yPred_gb)

print(f"MAE: {mae_gb:.3f}")
print(f"MSE: {mse_gb:.3f}")
print(f"RMSE: {rmse_gb:.3f}")
print(f"R²: {r2_gb:.3f}")
# Out:
# MAE: 0.203
# MSE: 0.085
# RMSE: 0.291
# R²: 0.706

# %% [markdown]
# 3.4. XGBoost

# %%
xgb = XGBRegressor(n_estimators=200, random_state=0)
xgb_cv_scores = cross_val_score(xgb, XTotal, YTotal, cv=cv, scoring='r2')
xgb.fit(XTrain, yTrain)
yPred_xgb = xgb.predict(XTest)

# Métricas
mae_xgb = mean_absolute_error(yTest, yPred_xgb)
mse_xgb = mean_squared_error(yTest, yPred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
r2_xgb = r2_score(yTest, yPred_xgb)

# Resultados
print(f"MAE: {mae_xgb:.3f}")
print(f"MSE: {mse_xgb:.3f}")
print(f"RMSE: {rmse_xgb:.3f}")
print(f"R²: {r2_xgb:.3f}")
# Out:
# MAE: 0.206
# MSE: 0.091
# RMSE: 0.301
# R²: 0.686

# %%
# Crear DataFrame con las métricas
df_metricas = pd.DataFrame({
    'Modelo': ['Regresión Lineal', 'Random Forest', 'Gradient Boosting', 'XGBoost'],
    'MAE': [mae_rl, mae_rf, mae_gb, mae_xgb],
    'RMSE': [rmse_rl, rmse_rf, rmse_gb, rmse_xgb],
    'R²': [r2_rl, r2_rf, r2_gb, r2_xgb]
})

print(df_metricas)
# Out:
#               Modelo       MAE      RMSE        R²
# 0   Regresión Lineal  0.195734  0.293990  0.700545
# 1      Random Forest  0.200361  0.293822  0.700887
# 2  Gradient Boosting  0.203117  0.291422  0.705754
# 3            XGBoost  0.206472  0.300911  0.686280
